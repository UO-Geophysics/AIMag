# %%
import pandas as pd
import numpy as np

metadata = pd.read_csv('/home/sdybing/mlaapde/mlaapde_metadata.csv')
# Out:
# /home/sdybing/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (38) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
metadata
# Out:
#          Unnamed: 0                      phase_id                   waves_id  \
# 0                 0   usc000irgm_GE.SNAA.BH*.--_P  usc000irgm_GE.SNAA.BH*.--
# 1                 1  usc000irgm_IU.PMSA.BH*.10_Sn  usc000irgm_IU.PMSA.BH*.10
# 2                 2   usc000irgm_IU.QSPA.BH*.10_P  usc000irgm_IU.QSPA.BH*.10
# 3                 3  usb000ikfk_AK.BPAW.BH*.--_Sn  usb000ikfk_AK.BPAW.BH*.--
# 4                 4  usb000ikfk_AK.BRLK.BH*.--_Pn  usb000ikfk_AK.BRLK.BH*.--
# ...             ...                           ...                        ...
# 5101562     5101562   us6000d4ny_AV.RED.BH*.--_Sn   us6000d4ny_AV.RED.BH*.--
# 5101563     5101563  us6000d4ny_IM.IL31.BH*.--_Pn  us6000d4ny_IM.IL31.BH*.--
# 5101564     5101564  us6000d4ny_IU.COLA.HH*.00_Pn  us6000d4ny_IU.COLA.HH*.00
# 5101565     5101565  us6000d4ny_TA.J18K.BH*.--_Pn  us6000d4ny_TA.J18K.BH*.--
# 5101566     5101566  us6000d4ny_TA.M17K.BH*.--_Pn  us6000d4ny_TA.M17K.BH*.--
#
# ...

# %%
phase_id = metadata['phase_id']

# %%
phase_id
# Out:
# 0           usc000irgm_GE.SNAA.BH*.--_P
# 1          usc000irgm_IU.PMSA.BH*.10_Sn
# 2           usc000irgm_IU.QSPA.BH*.10_P
# 3          usb000ikfk_AK.BPAW.BH*.--_Sn
# 4          usb000ikfk_AK.BRLK.BH*.--_Pn
#                        ...
# 5101562     us6000d4ny_AV.RED.BH*.--_Sn
# 5101563    us6000d4ny_IM.IL31.BH*.--_Pn
# 5101564    us6000d4ny_IU.COLA.HH*.00_Pn
# 5101565    us6000d4ny_TA.J18K.BH*.--_Pn
# 5101566    us6000d4ny_TA.M17K.BH*.--_Pn
# Name: phase_id, Length: 5101567, dtype: object

# %%
import time
print(time.ctime())
# Out:
# Fri Feb 10 15:01:40 2023
